# %%
#gmail contacts analyzer --> requires oauth 
#facebook friends analyzer --> requires fb dev account 
#linkedIn friends analyzer --> requires linkedin dev account 

#voice control HTML --> doable voice-beta.html 
#google search of news and name --> doable 
#named entity recognition from description  --> doable

#meetups API --> suggested events --> doable 


#multiple examples of networks --> doable --> database manipulation 

import smtplib
import time
import imaplib
import email

FROM_EMAIL = "wu4school@gmail.com"
FROM_PWD = "WellHello34"
SMTP_SERVER = "smtp.gmail.com"
def read_email_from_gmail():
    try:
        mail = imaplib.IMAP4_SSL(SMTP_SERVER)
        mail.login(FROM_EMAIL,FROM_PWD)
        mail.select('inbox')
        print(mail)
        type, data = mail.search(None, 'ALL')
        mail_ids = data[0]

        id_list = mail_ids.split()   
        first_email_id = int(id_list[0])
        latest_email_id = int(id_list[-1])


        for i in range(latest_email_id,first_email_id, -1):
            typ, data = mail.fetch(i, '(RFC822)' )

            for response_part in data:
                if isinstance(response_part, tuple):
                    msg = email.message_from_string(response_part[1])
                    email_subject = msg['subject']
                    email_from = msg['from']
                    print('From : ' + email_from + '\n')
                    print('Subject : ' + email_subject + '\n')

    except Exception:
        print(Exception.error)
        
read_email_from_gmail()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-17-b821599ce06a> in read_email_from_gmail()
#      11         mail = imaplib.IMAP4_SSL(SMTP_SERVER)
# ---> 12         mail.login(FROM_EMAIL,FROM_PWD)
#      13         mail.select('inbox')
#
# C:\ProgramData\Miniconda3\lib\imaplib.py in login(self, user, password)
#     592         if typ != 'OK':
# --> 593             raise self.error(dat[-1])
#     594         self.state = 'AUTH'
#
# error: b'[ALERT] Please log in via your web browser: https://support.google.com/mail/accounts/answer/78754 (Failure)'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-b821599ce06a> in <module>()
#      35         print(Exception.error)
#      36
# ---> 37 read_email_from_gmail()
#
# <ipython-input-17-b821599ce06a> in read_email_from_gmail()
#      33
#      34     except Exception:
# ---> 35         print(Exception.error)
#      36
#      37 read_email_from_gmail()
#
# AttributeError: type object 'Exception' has no attribute 'error'

# %%
from googlesearch import search
for url in search('Tiffany Dufu news', stop=3):
    print(url)
# Out:
# http://tiffanydufu.com/
# http://tiffanydufu.com/about/
# http://tiffanydufu.com/drop-the-ball/
# http://tiffanydufu.com/thoughts/
# http://tiffanydufu.com/speaking/
# https://www.forbes.com/sites/emiliearies/2017/02/23/how-tiffany-dufu-is-achieving-more-by-doing-less/
# https://www.nytimes.com/2017/01/14/nyregion/tiffany-dufu-sunday-routine.html
# https://twitter.com/tdufu?lang=en
# https://theblog.adobe.com/tiffany-dufu/
# https://news.rocketsofawesome.com/tiffany-dufu-drop-the-ball/
# https://www.facebook.com/tiffanydufu/
# http://time.com/4710852/overworked-women-tiffany-dufu-book-drop-the-ball/
# https://www.linkedin.com/in/tiffanydufu

# %%
from textblob import TextBlob 

#Execute "nltk.download()" and copy it to the root folder of your AWS lambda application. (The folder should be called "nltk_data".)
#In the user interface of your lambda function (in the AWS console), you add "NLTK_DATA" = "./nltk_data". Please see the image. 

txt = """She is a biomedical student at Columbia university. She does research at the labs in the summer"""
blob = TextBlob(txt)
print(blob.noun_phrases)
# Out:
# ['biomedical student', 'columbia']

# %%
import requests
import json
import time

def main(): 
    cities =[("Bridgeport","CT")]
    api_key= "4b2b7c173622721682d505b38682421" 
    for (city, state) in cities:
        per_page = 200
        results_we_got = per_page
        offset = 0
        while (results_we_got == per_page):
            # Meetup.com documentation here: http://www.meetup.com/meetup_api/docs/2/groups/
            response=get_results({"sign":"true","country":"US", "city":city, "state":state, "radius": 10, "key":api_key, "page":per_page, "offset":offset })
            time.sleep(1)
            offset += 1
            n = len(response.keys())
            print(json.dumps(response))
                #category = ""
                #if "category" in group:
                #    category = group['category']['name']
                #print([city, group['name'].replace(","," "), group['created'], group['city'],group.get('state',""),category,group['members'], group.get('who',"").replace(","," ")])



def get_results(params):
    request = requests.get("http://api.meetup.com/find/upcoming_events",params=params)
    data = request.json()
    return data

main()
# Out:
# {"city": {"id": 94022, "city": "Los Altos", "lat": 37.37, "lon": -122.14, "state": "CA", "country": "us", "zip": "94022", "member_count": 1169}, "events": [{"link": "https://www.meetup.com/EXPLORETHEBAY/events/250305674/", "visibility": "public_limited", "group": {"created": 1390978902000, "name": "*Explore The Bay (ETB)", "id": 12564822, "join_mode": "approval", "lat": 37.380001068115234, "lon": -122.08000183105469, "urlname": "EXPLORETHEBAY", "who": "Explorers", "localized_location": "Mountain View, CA", "region": "en_US"}, "waitlist_count": 0, "yes_rsvp_count": 37, "duration": 14400000, "time": 1525831200000, "utc_offset": -25200000, "name": "Karaoke and dancing", "id": "250305674"}, {"link": "https://www.meetup.com/EXPLORETHEBAY/events/250384793/", "visibility": "public_limited", "group": {"created": 1390978902000, "name": "*Explore The Bay (ETB)", "id": 12564822, "join_mode": "approval", "lat": 37.380001068115234, "lon": -122.08000183105469, "urlname": "EXPLORETHEBAY", "who": "Explorers", "localized_location": "Mountain View, CA", "region": "en_US"}, "waitlist_count": 1, "yes_rsvp_count": 140, "duration": 12600000, "time": 1526088600000, "utc_offset": -25200000, "name": "New Member Extended Happy Hour Mixer in Palo Alto", "id": "250384793"}, {"link": "https://www.meetup.com/EXPLORETHEBAY/events/249852907/", "visibility": "public_limited", "group": {"created": 1390978902000, "name": "*Explore The Bay (ETB)", "id": 12564822, "join_mode": "approval", "lat": 37.380001068115234, "lon": -122.08000183105469, "urlname": "EXPLORETHEBAY", "who": "Explorers", "localized_location": "Mountain View, CA", "region": "en_US"}, "waitlist_count": 0, "yes_rsvp_count": 131, "duration": 14400000, "time": 1526605200000, "utc_offset": -25200000, "name": "Craft Cocktails and Live DJ in Palo Alto", "id": "249852907"}, {"link": "https://www.meetup.com/eventsoftribe/events/250223953/", "visibility": "public_limited", "group": {"created": 1519360586000, "name": "Tribe [21-32]", "id": 27618019, "join_mode": "approval", "lat": 37.439998626708984, "lon": -122.1500015258789, "urlname": "eventsoftribe", "who": "Tribesmen", "localized_location": "Palo Alto, CA", "region": "en_US"}, "waitlist_count": 0, "yes_rsvp_count": 24, "duration": 9000000, "time": 1526000400000, "utc_offset": -25200000, "name": "Newbie Happy Hour - Welcome to the Tribe ", "id": "250223953"}, {"link": "https://www.meetup.com/eventsoftribe/events/249987045/", "visibility": "public_limited", "group": {"created": 1519360586000, "name": "Tribe [21-32]", "id": 27618019, "join_mode": "approval", "lat": 37.439998626708984, "lon": -122.1500015258789, "urlname": "eventsoftribe", "who": "Tribesmen", "localized_location": "Palo Alto, CA", "region": "en_US"}, "waitlist_count": 1, "yes_rsvp_count": 10, "duration": 7200000, "time": 1526436000000, "utc_offset": -25200000, "name": "New Member Dinner Tuesdays- Palo Alto Downtown", "id": "249987045"}, {"link": "https://www.meetup.com/45-South-Bay-Social-Singles/events/250188367/", "visibility": "public_limited", "group": {"created": 1329707941000, "name": "45+ South Bay Social & Hiking Singles", "id": 3326562, "join_mode": "approval", "lat": 37.310001373291016, "lon": -121.80999755859375, "urlname": "45-South-Bay-Social-Singles", "who": "soloes", "localized_location": "San Jose, CA", "region": "en_US"}, "waitlist_count": 0, "yes_rsvp_count": 8, "duration": 7500000, "time": 1526003700000, "utc_offset": -25200000, "name": "Flute Music from Mexican Composers in California", "id": "250188367"}, {"link": "https://www.meetup.com/45-South-Bay-Social-Singles/events/250237428/", "visibility": "public_limited", "group": {"created": 1329707941000, "name": "45+ South Bay Social & Hiking Singles", "id": 3326562, "join_mode": "approval", "lat": 37.310001373291016, "lon": -121.80999755859375, "urlname": "45-South-Bay-Social-Singles", "who": "soloes", "localized_location": "San Jose, CA", "region": "en_US"}, "waitlist_count": 4, "yes_rsvp_count": 33, "duration": 180000 ...
# {"city": {"id": 94022, "city": "Los Altos", "lat": 37.37, "lon": -122.14, "state": "CA", "country": "us", "zip": "94022", "member_count": 1169}, "events": [{"link": "https://www.meetup.com/EXPLORETHEBAY/events/248649180/", "visibility": "public_limited", "group": {"created": 1390978902000, "name": "*Explore The Bay (ETB)", "id": 12564822, "join_mode": "approval", "lat": 37.380001068115234, "lon": -122.08000183105469, "urlname": "EXPLORETHEBAY", "who": "Explorers", "localized_location": "Mountain View, CA", "region": "en_US"}, "waitlist_count": 0, "yes_rsvp_count": 82, "duration": 7200000, "time": 1526857200000, "utc_offset": -25200000, "name": "Happy Hour with friends", "id": "248649180"}, {"link": "https://www.meetup.com/eventsoftribe/events/250460742/", "visibility": "public_limited", "group": {"created": 1519360586000, "name": "Tribe [21-32]", "id": 27618019, "join_mode": "approval", "lat": 37.439998626708984, "lon": -122.1500015258789, "urlname": "eventsoftribe", "who": "Tribesmen", "localized_location": "Palo Alto, CA", "region": "en_US"}, "waitlist_count": 0, "yes_rsvp_count": 12, "duration": 9000000, "time": 1527301800000, "utc_offset": -25200000, "name": "Newbie Happy Hour - Welcome to the Tribe ", "id": "250460742"}, {"link": "https://www.meetup.com/EXPLORETHEBAY/events/249395852/", "visibility": "public_limited", "group": {"created": 1390978902000, "name": "*Explore The Bay (ETB)", "id": 12564822, "join_mode": "approval", "lat": 37.380001068115234, "lon": -122.08000183105469, "urlname": "EXPLORETHEBAY", "who": "Explorers", "localized_location": "Mountain View, CA", "region": "en_US"}, "waitlist_count": 9, "yes_rsvp_count": 27, "duration": 10800000, "time": 1527955200000, "utc_offset": -25200000, "name": "Food Bank 29: Package Food for the Homeless & Less Fortunate in SJ", "id": "249395852"}, {"link": "https://www.meetup.com/eventsoftribe/events/250525750/", "visibility": "public_limited", "group": {"created": 1519360586000, "name": "Tribe [21-32]", "id": 27618019, "join_mode": "approval", "lat": 37.439998626708984, "lon": -122.1500015258789, "urlname": "eventsoftribe", "who": "Tribesmen", "localized_location": "Palo Alto, CA", "region": "en_US"}, "waitlist_count": 0, "yes_rsvp_count": 14, "duration": 10800000, "time": 1526263200000, "utc_offset": -25200000, "name": "Poker Night- Beginner Friendly", "id": "250525750"}, {"link": "https://www.meetup.com/eventsoftribe/events/250215035/", "visibility": "public_limited", "group": {"created": 1519360586000, "name": "Tribe [21-32]", "id": 27618019, "join_mode": "approval", "lat": 37.439998626708984, "lon": -122.1500015258789, "urlname": "eventsoftribe", "who": "Tribesmen", "localized_location": "Palo Alto, CA", "region": "en_US"}, "waitlist_count": 0, "yes_rsvp_count": 8, "duration": 7200000, "time": 1527732000000, "utc_offset": -25200000, "name": "The Cocktail Book Club!!", "id": "250215035"}, {"link": "https://www.meetup.com/EXPLORETHEBAY/events/249848167/", "visibility": "public_limited", "group": {"created": 1390978902000, "name": "*Explore The Bay (ETB)", "id": 12564822, "join_mode": "approval", "lat": 37.380001068115234, "lon": -122.08000183105469, "urlname": "EXPLORETHEBAY", "who": "Explorers", "localized_location": "Mountain View, CA", "region": "en_US"}, "waitlist_count": 0, "yes_rsvp_count": 19, "duration": 10200000, "time": 1526006400000, "utc_offset": -25200000, "name": "La Cage Aux Folles, musical", "id": "249848167"}, {"link": "https://www.meetup.com/45-South-Bay-Social-Singles/events/248562730/", "visibility": "public_limited", "group": {"created": 1329707941000, "name": "45+ South Bay Social & Hiking Singles", "id": 3326562, "join_mode": "approval", "lat": 37.310001373291016, "lon": -121.80999755859375, "urlname": "45-South-Bay-Social-Singles", "who": "soloes", "localized_location": "San Jose, CA", "region": "en_US"}, "waitlist_count": 0, "yes_rsvp_count": 4, "duration": 18300000, "time": 1526741700000, "utc_offset": -25200000, "name": "El Corte de Madera Pho ...
# {"city": {"id": 94022, "city": "Los Altos", "lat": 37.37, "lon": -122.14, "state": "CA", "country": "us", "zip": "94022", "member_count": 1169}, "events": [{"link": "https://www.meetup.com/eventsoftribe/events/250317201/", "visibility": "public_limited", "group": {"created": 1519360586000, "name": "Tribe [21-32]", "id": 27618019, "join_mode": "approval", "lat": 37.439998626708984, "lon": -122.1500015258789, "urlname": "eventsoftribe", "who": "Tribesmen", "localized_location": "Palo Alto, CA", "region": "en_US"}, "waitlist_count": 0, "yes_rsvp_count": 7, "duration": 9000000, "time": 1527211800000, "utc_offset": -25200000, "name": "Dinner & Drinks (Only for organizers)", "id": "250317201"}, {"link": "https://www.meetup.com/eventsoftribe/events/250122152/", "visibility": "public_limited", "group": {"created": 1519360586000, "name": "Tribe [21-32]", "id": 27618019, "join_mode": "approval", "lat": 37.439998626708984, "lon": -122.1500015258789, "urlname": "eventsoftribe", "who": "Tribesmen", "localized_location": "Palo Alto, CA", "region": "en_US"}, "waitlist_count": 0, "yes_rsvp_count": 10, "duration": 10800000, "time": 1527822000000, "utc_offset": -25200000, "name": "SF Bring Down the House", "id": "250122152"}, {"link": "https://www.meetup.com/eventsoftribe/events/250122066/", "visibility": "public_limited", "group": {"created": 1519360586000, "name": "Tribe [21-32]", "id": 27618019, "join_mode": "approval", "lat": 37.439998626708984, "lon": -122.1500015258789, "urlname": "eventsoftribe", "who": "Tribesmen", "localized_location": "Palo Alto, CA", "region": "en_US"}, "waitlist_count": 0, "yes_rsvp_count": 12, "duration": 21600000, "time": 1528056000000, "utc_offset": -25200000, "name": "Summer Sundays at Dolores Park", "id": "bhbhqpyxjbfb"}, {"link": "https://www.meetup.com/EXPLORETHEBAY/events/249620263/", "visibility": "public_limited", "group": {"created": 1390978902000, "name": "*Explore The Bay (ETB)", "id": 12564822, "join_mode": "approval", "lat": 37.380001068115234, "lon": -122.08000183105469, "urlname": "EXPLORETHEBAY", "who": "Explorers", "localized_location": "Mountain View, CA", "region": "en_US"}, "waitlist_count": 0, "yes_rsvp_count": 45, "duration": 9000000, "time": 1526520600000, "utc_offset": -25200000, "name": "Daniel Castro Band at Club Fox!", "id": "249620263"}, {"link": "https://www.meetup.com/Lovely-Ladies-Happy-Hours-Bay-Area-20s-30s/events/250523967/", "visibility": "public_limited", "group": {"created": 1432446772000, "name": "Ladies Happy Hours - Peninsula Late 20s to Early 40s", "id": 18620797, "join_mode": "approval", "lat": 37.439998626708984, "lon": -122.1500015258789, "urlname": "Lovely-Ladies-Happy-Hours-Bay-Area-20s-30s", "who": "Happy Ladies!", "localized_location": "Palo Alto, CA", "region": "en_US"}, "waitlist_count": 0, "yes_rsvp_count": 3, "duration": 871200000, "time": 1526607000000, "utc_offset": -25200000, "name": "Dinner @ Oren's Hummus", "id": "250523967"}, {"link": "https://www.meetup.com/Lovely-Ladies-Happy-Hours-Bay-Area-20s-30s/events/250021120/", "visibility": "public_limited", "group": {"created": 1432446772000, "name": "Ladies Happy Hours - Peninsula Late 20s to Early 40s", "id": 18620797, "join_mode": "approval", "lat": 37.439998626708984, "lon": -122.1500015258789, "urlname": "Lovely-Ladies-Happy-Hours-Bay-Area-20s-30s", "who": "Happy Ladies!", "localized_location": "Palo Alto, CA", "region": "en_US"}, "waitlist_count": 2, "yes_rsvp_count": 2, "duration": 7200000, "time": 1526857200000, "utc_offset": -25200000, "name": "Ladies High Tea ($30 includes tax and tip)", "id": "250021120"}, {"link": "https://www.meetup.com/Lovely-Ladies-Happy-Hours-Bay-Area-20s-30s/events/250052358/", "visibility": "public_limited", "group": {"created": 1432446772000, "name": "Ladies Happy Hours - Peninsula Late 20s to Early 40s", "id": 18620797, "join_mode": "approval", "lat": 37.439998626708984, "lon": -122.1500015258789, "urlname": "Lovely-Ladies-Happy-Hours-Bay-Area-20s-30s", "who": "Happy Ladies!", ...
# {"city": {"id": 94022, "city": "Los Altos", "lat": 37.37, "lon": -122.14, "state": "CA", "country": "us", "zip": "94022", "member_count": 1169}, "events": [{"link": "https://www.meetup.com/eventsoftribe/events/250502075/", "visibility": "public_limited", "group": {"created": 1519360586000, "name": "Tribe [21-32]", "id": 27618019, "join_mode": "approval", "lat": 37.439998626708984, "lon": -122.1500015258789, "urlname": "eventsoftribe", "who": "Tribesmen", "localized_location": "Palo Alto, CA", "region": "en_US"}, "waitlist_count": 0, "yes_rsvp_count": 4, "duration": 14400000, "time": 1526169600000, "utc_offset": -25200000, "name": "Deduction Game Night!", "id": "250502075"}, {"link": "https://www.meetup.com/eventsoftribe/events/249304502/", "visibility": "public_limited", "group": {"created": 1519360586000, "name": "Tribe [21-32]", "id": 27618019, "join_mode": "approval", "lat": 37.439998626708984, "lon": -122.1500015258789, "urlname": "eventsoftribe", "who": "Tribesmen", "localized_location": "Palo Alto, CA", "region": "en_US"}, "waitlist_count": 0, "yes_rsvp_count": 8, "duration": 338400000, "time": 1526612400000, "utc_offset": -25200000, "name": "EDC Music Festival in Vegas", "id": "249304502"}, {"link": "https://www.meetup.com/eventsoftribe/events/250488012/", "visibility": "public_limited", "group": {"created": 1519360586000, "name": "Tribe [21-32]", "id": 27618019, "join_mode": "approval", "lat": 37.439998626708984, "lon": -122.1500015258789, "urlname": "eventsoftribe", "who": "Tribesmen", "localized_location": "Palo Alto, CA", "region": "en_US"}, "waitlist_count": 0, "yes_rsvp_count": 10, "duration": 7200000, "time": 1526752800000, "utc_offset": -25200000, "name": "Hike at Rancho San Antonio ", "id": "250488012"}, {"link": "https://www.meetup.com/bayarea-tennis/events/250365106/", "visibility": "public_limited", "group": {"created": 1205798442000, "name": "Bay Area Tennis", "id": 1068132, "join_mode": "approval", "lat": 37.380001068115234, "lon": -122.08000183105469, "urlname": "bayarea-tennis", "who": "Tennis Players", "localized_location": "Mountain View, CA", "region": "en_US"}, "waitlist_count": 0, "yes_rsvp_count": 2, "duration": 10800000, "time": 1527208200000, "utc_offset": -25200000, "name": "Thursday Evening Tennis", "id": "qhdsdpyxhbgc"}, {"link": "https://www.meetup.com/bayarea-tennis/events/250365118/", "visibility": "public_limited", "group": {"created": 1205798442000, "name": "Bay Area Tennis", "id": 1068132, "join_mode": "approval", "lat": 37.380001068115234, "lon": -122.08000183105469, "urlname": "bayarea-tennis", "who": "Tennis Players", "localized_location": "Mountain View, CA", "region": "en_US"}, "waitlist_count": 0, "yes_rsvp_count": 2, "duration": 7200000, "time": 1527216300000, "utc_offset": -25200000, "name": "Thursday Night Tennis", "id": "ljdsdpyxhbgc"}, {"link": "https://www.meetup.com/bayarea-tennis/events/250365147/", "visibility": "public_limited", "group": {"created": 1205798442000, "name": "Bay Area Tennis", "id": 1068132, "join_mode": "approval", "lat": 37.380001068115234, "lon": -122.08000183105469, "urlname": "bayarea-tennis", "who": "Tennis Players", "localized_location": "Mountain View, CA", "region": "en_US"}, "waitlist_count": 0, "yes_rsvp_count": 2, "duration": 10800000, "time": 1527813000000, "utc_offset": -25200000, "name": "Thursday Evening Tennis", "id": "qhdsdpyxhbpc"}, {"link": "https://www.meetup.com/AnythingFun/events/249160528/", "visibility": "public_limited", "group": {"created": 1170391485000, "name": "Bay Area Hiking And Anything Fun", "id": 419553, "join_mode": "approval", "lat": 37.310001373291016, "lon": -122.0, "urlname": "AnythingFun", "who": "Adventure Seekers", "localized_location": "San Jose, CA", "region": "en_US"}, "waitlist_count": 0, "yes_rsvp_count": 3, "duration": 6300000, "time": 1525916700000, "utc_offset": -25200000, "name": "Trivia night at New Jersey's", "id": "249160528"}, {"link": "https://www.meetup.com/AnythingFun/events/249921522/", "visibility" ...
# {"city": {"id": 94022, "city": "Los Altos", "lat": 37.37, "lon": -122.14, "state": "CA", "country": "us", "zip": "94022", "member_count": 1169}, "events": [{"link": "https://www.meetup.com/eventsoftribe/events/250557586/", "visibility": "public_limited", "group": {"created": 1519360586000, "name": "Tribe [21-32]", "id": 27618019, "join_mode": "approval", "lat": 37.439998626708984, "lon": -122.1500015258789, "urlname": "eventsoftribe", "who": "Tribesmen", "localized_location": "Palo Alto, CA", "region": "en_US"}, "waitlist_count": 0, "yes_rsvp_count": 14, "duration": 14400000, "time": 1526839200000, "utc_offset": -25200000, "name": "It's A Lazy Sunday Kinda Pool Party/BBQ", "id": "250557586"}, {"link": "https://www.meetup.com/bayarea-tennis/events/250461836/", "visibility": "public_limited", "group": {"created": 1205798442000, "name": "Bay Area Tennis", "id": 1068132, "join_mode": "approval", "lat": 37.380001068115234, "lon": -122.08000183105469, "urlname": "bayarea-tennis", "who": "Tennis Players", "localized_location": "Mountain View, CA", "region": "en_US"}, "waitlist_count": 0, "yes_rsvp_count": 4, "duration": 10800000, "time": 1526085000000, "utc_offset": -25200000, "name": "Friday Tennis in Sunnyvale", "id": "qktwhpyxhbpb"}, {"link": "https://www.meetup.com/AnythingFun/events/249160528/", "visibility": "public_limited", "group": {"created": 1170391485000, "name": "Bay Area Hiking And Anything Fun", "id": 419553, "join_mode": "approval", "lat": 37.310001373291016, "lon": -122.0, "urlname": "AnythingFun", "who": "Adventure Seekers", "localized_location": "San Jose, CA", "region": "en_US"}, "waitlist_count": 0, "yes_rsvp_count": 3, "duration": 6300000, "time": 1525916700000, "utc_offset": -25200000, "name": "Trivia night at New Jersey's", "id": "249160528"}, {"link": "https://www.meetup.com/bayarea-tennis/events/250499554/", "visibility": "public_limited", "group": {"created": 1205798442000, "name": "Bay Area Tennis", "id": 1068132, "join_mode": "approval", "lat": 37.380001068115234, "lon": -122.08000183105469, "urlname": "bayarea-tennis", "who": "Tennis Players", "localized_location": "Mountain View, CA", "region": "en_US"}, "waitlist_count": 0, "yes_rsvp_count": 2, "duration": 10800000, "time": 1526079600000, "utc_offset": -25200000, "name": "Flexible Fridays in Redwood City", "id": "nvnnlpyxhbpb"}, {"link": "https://www.meetup.com/bayarea-tennis/events/250552293/", "visibility": "public_limited", "group": {"created": 1205798442000, "name": "Bay Area Tennis", "id": 1068132, "join_mode": "approval", "lat": 37.380001068115234, "lon": -122.08000183105469, "urlname": "bayarea-tennis", "who": "Tennis Players", "localized_location": "Mountain View, CA", "region": "en_US"}, "waitlist_count": 0, "yes_rsvp_count": 2, "duration": 10800000, "time": 1526248800000, "utc_offset": -25200000, "name": "Sunday Advanced (4.0+) Tennis", "id": "fzlrmpyxhbrb"}, {"link": "https://www.meetup.com/AnythingFun/events/249160535/", "visibility": "public_limited", "group": {"created": 1170391485000, "name": "Bay Area Hiking And Anything Fun", "id": 419553, "join_mode": "approval", "lat": 37.310001373291016, "lon": -122.0, "urlname": "AnythingFun", "who": "Adventure Seekers", "localized_location": "San Jose, CA", "region": "en_US"}, "waitlist_count": 0, "yes_rsvp_count": 2, "duration": 6300000, "time": 1526521500000, "utc_offset": -25200000, "name": "Trivia night at New Jersey's", "id": "249160535"}, {"link": "https://www.meetup.com/AnythingFun/events/250465249/", "visibility": "public_limited", "group": {"created": 1170391485000, "name": "Bay Area Hiking And Anything Fun", "id": 419553, "join_mode": "approval", "lat": 37.310001373291016, "lon": -122.0, "urlname": "AnythingFun", "who": "Adventure Seekers", "localized_location": "San Jose, CA", "region": "en_US"}, "waitlist_count": 0, "yes_rsvp_count": 2, "duration": 6300000, "time": 1528335900000, "utc_offset": -25200000, "name": "Trivia night at New Jersey's", "id": "250465249"}, {"created": 1516759587 ...
# {"city": {"id": 94022, "city": "Los Altos", "lat": 37.37, "lon": -122.14, "state": "CA", "country": "us", "zip": "94022", "member_count": 1169}, "events": [{"link": "https://www.meetup.com/AnythingFun/events/244506418/", "visibility": "public_limited", "group": {"created": 1170391485000, "name": "Bay Area Hiking And Anything Fun", "id": 419553, "join_mode": "approval", "lat": 37.310001373291016, "lon": -122.0, "urlname": "AnythingFun", "who": "Adventure Seekers", "localized_location": "San Jose, CA", "region": "en_US"}, "waitlist_count": 0, "yes_rsvp_count": 2, "duration": 6300000, "time": 1527731100000, "utc_offset": -25200000, "name": "Trivia night at New Jersey's", "id": "244506418"}, {"link": "https://www.meetup.com/bayarea-tennis/events/250520907/", "visibility": "public_limited", "group": {"created": 1205798442000, "name": "Bay Area Tennis", "id": 1068132, "join_mode": "approval", "lat": 37.380001068115234, "lon": -122.08000183105469, "urlname": "bayarea-tennis", "who": "Tennis Players", "localized_location": "Mountain View, CA", "region": "en_US"}, "waitlist_count": 0, "yes_rsvp_count": 5, "duration": 10800000, "time": 1526218200000, "utc_offset": -25200000, "name": "Sunday Morning 3.5~4.0 Tennis in Sunnyvale / Mountain View", "id": "bbbpnpyxhbrb"}, {"link": "https://www.meetup.com/AnythingFun/events/249910107/", "visibility": "public_limited", "group": {"created": 1170391485000, "name": "Bay Area Hiking And Anything Fun", "id": 419553, "join_mode": "approval", "lat": 37.310001373291016, "lon": -122.0, "urlname": "AnythingFun", "who": "Adventure Seekers", "localized_location": "San Jose, CA", "region": "en_US"}, "waitlist_count": 0, "yes_rsvp_count": 1, "time": 1526698800000, "utc_offset": -25200000, "name": "May Ride with SJ Bike Party", "id": "249910107"}, {"link": "https://www.meetup.com/bayarea-tennis/events/248845102/", "visibility": "public_limited", "group": {"created": 1205798442000, "name": "Bay Area Tennis", "id": 1068132, "join_mode": "approval", "lat": 37.380001068115234, "lon": -122.08000183105469, "urlname": "bayarea-tennis", "who": "Tennis Players", "localized_location": "Mountain View, CA", "region": "en_US"}, "waitlist_count": 0, "yes_rsvp_count": 1, "duration": 7200000, "time": 1527980400000, "utc_offset": -25200000, "name": "Saturday 3.0+ Tennis", "id": "pwjtqpyxjbdb"}, {"link": "https://www.meetup.com/AnythingFun/events/250315264/", "visibility": "public_limited", "group": {"created": 1170391485000, "name": "Bay Area Hiking And Anything Fun", "id": 419553, "join_mode": "approval", "lat": 37.310001373291016, "lon": -122.0, "urlname": "AnythingFun", "who": "Adventure Seekers", "localized_location": "San Jose, CA", "region": "en_US"}, "waitlist_count": 0, "yes_rsvp_count": 3, "duration": 6300000, "time": 1527453900000, "utc_offset": -25200000, "name": "Outdoor archery lesson plus short walk along archery trail", "id": "250315264"}, {"link": "https://www.meetup.com/bayarea-tennis/events/250564406/", "visibility": "public_limited", "group": {"created": 1205798442000, "name": "Bay Area Tennis", "id": 1068132, "join_mode": "approval", "lat": 37.380001068115234, "lon": -122.08000183105469, "urlname": "bayarea-tennis", "who": "Tennis Players", "localized_location": "Mountain View, CA", "region": "en_US"}, "waitlist_count": 0, "yes_rsvp_count": 3, "duration": 10800000, "time": 1526252400000, "utc_offset": -25200000, "name": "3.0+ Redwood City Sunday Afternoon Tennis", "id": "wxfrnpyxhbrb"}, {"created": 1525687174000, "duration": 7200000, "id": "250539295", "name": "How to Plan Projects as a Product Manager by former Microsoft PM", "status": "upcoming", "time": 1527816600000, "local_date": "2018-05-31", "local_time": "18:30", "updated": 1525687898000, "utc_offset": -25200000, "waitlist_count": 0, "yes_rsvp_count": 4, "venue": {"id": 24550679, "name": "Product School Silicon Valley", "lat": 37.395042419433594, "lon": -121.97842407226562, "repinned": false, "address_1": "4500 Great America Pkwy", "city": "Santa C ...
# {"city": {"id": 94022, "city": "Los Altos", "lat": 37.37, "lon": -122.14, "state": "CA", "country": "us", "zip": "94022", "member_count": 1169}, "events": [{"link": "https://www.meetup.com/bayarea-tennis/events/250559383/", "visibility": "public_limited", "group": {"created": 1205798442000, "name": "Bay Area Tennis", "id": 1068132, "join_mode": "approval", "lat": 37.380001068115234, "lon": -122.08000183105469, "urlname": "bayarea-tennis", "who": "Tennis Players", "localized_location": "Mountain View, CA", "region": "en_US"}, "waitlist_count": 0, "yes_rsvp_count": 3, "duration": 7200000, "time": 1526248800000, "utc_offset": -25200000, "name": "Sunday Afternoon Sunnyvale Tennis", "id": "kwtdfpyxhbrb"}, {"created": 1468361297000, "id": "gttbwlyxhbnb", "name": "Drop-in   Chess", "status": "upcoming", "time": 1525987800000, "local_date": "2018-05-10", "local_time": "14:30", "updated": 1468361297000, "utc_offset": -25200000, "waitlist_count": 0, "yes_rsvp_count": 1, "venue": {"id": 10497992, "name": "Sunnyvale City Senior Center", "lat": 37.35781478881836, "lon": -122.0263900756836, "repinned": false, "address_1": "550 East Remington Drive", "city": "Sunnyvale", "country": "us", "localized_country_name": "USA", "zip": "94087", "state": "CA"}, "group": {"created": 1286496191000, "name": "Sunnyvale Community Center", "id": 1718732, "join_mode": "open", "lat": 37.380001068115234, "lon": -122.0199966430664, "urlname": "SunnyvaleCommunityCenter", "who": "Sunnyvale Fans", "localized_location": "Sunnyvale, CA", "region": "en_US"}, "link": "https://www.meetup.com/SunnyvaleCommunityCenter/events/249989301/", "description": "<p>Drop in for an afternoon of chess.\u00a0Newcomers are welcome and encouraged to join us!</p> <p>First Come, First Serve. Please call ahead for space availability.<br/>Location: Cypress Room</p> <p>Free for members, $2 drop-in fee for non-members</p> <p>For more information please call[masked]</p> ", "visibility": "public"}, {"created": 1520308418000, "duration": 10800000, "id": "248457749", "name": "RARE EVENT: Dave Mendlen, General Manager @Microsoft & Bill Gates' speechwriter", "rsvp_limit": 100, "status": "upcoming", "time": 1526517900000, "local_date": "2018-05-16", "local_time": "17:45", "updated": 1520353627000, "utc_offset": -25200000, "waitlist_count": 20, "yes_rsvp_count": 100, "venue": {"id": 24773158, "name": "Procopio", "lat": 0.0, "lon": 0.0, "repinned": false, "address_1": "1117 California Ave", "city": "Palo Alto", "country": "us", "localized_country_name": "USA", "zip": "", "state": "CA"}, "group": {"created": 1335506529000, "name": "Silicon Valley Startup Incubation and Acceleration", "id": 3751852, "join_mode": "open", "lat": 37.349998474121094, "lon": -121.9800033569336, "urlname": "svsian", "who": "entrepreneurs", "localized_location": "Santa Clara, CA", "region": "en_US"}, "link": "https://www.meetup.com/svsian/events/248457749/", "description": "<p>RSVP HERE: <a href=\"https://www.lifograph.com/events/43142530470\"><a href=\"https://www.lifograph.com/events/43142530470\" class=\"linkified\">https://www.lifograph.com/events/43142530470</a></a></p> <p>Join us for a RARE occassion to meet and listen to Dave Mendlen, General Manager at <a href=\"http://www.microsoft.com/\">Microsoft</a>, as he is being interviewed fire-side chat style by Dea Wilson, Founder of <a href=\"https://www.lifograph.com/\">Lifograph </a>- the Wiki of People.</p> <p>Dave will fly in from Seattle just to share his stories with our Lifograph community.</p> <p>This is a RARE event and we expect to sell out. Reserve your tickets early.</p> <p>Drinks and Chinese food dinner will be provided.</p> <p>RSVP HERE: <a href=\"https://www.lifograph.com/events/43142530470\"><a href=\"https://www.lifograph.com/events/43142530470\" class=\"linkified\">https://www.lifograph.com/events/43142530470</a></a></p> <p>_________________________</p> <p>SPEAKER</p> <p>_________________________</p> <p>DAVE MENDLEN</p> <p>Dave Mendlen is General Manager a ...
# {"city": {"id": 94022, "city": "Los Altos", "lat": 37.37, "lon": -122.14, "state": "CA", "country": "us", "zip": "94022", "member_count": 1169}, "events": [{"created": 1446989853000, "id": "wnbcmlyxhbqb", "name": "Dawn (T,H,S,S) at Mitchell", "status": "upcoming", "time": 1526130900000, "local_date": "2018-05-12", "local_time": "06:15", "updated": 1446989853000, "utc_offset": -25200000, "waitlist_count": 0, "yes_rsvp_count": 1, "venue": {"id": 704101, "name": "Mitchell Park", "lat": 37.423133850097656, "lon": -122.11682891845703, "repinned": false, "address_1": "600 E Meadow Dr", "city": "Palo Alto", "country": "us", "localized_country_name": "USA", "phone": "6507146850", "zip": "94306", "state": "CA"}, "group": {"created": 1406576011000, "name": "Tennis Palo Alto", "id": 16034992, "join_mode": "approval", "lat": 37.439998626708984, "lon": -122.1500015258789, "urlname": "TennisPaloAlto", "who": "Members", "localized_location": "Palo Alto, CA", "region": "en_US"}, "link": "https://www.meetup.com/TennisPaloAlto/events/250034141/", "visibility": "public"}, {"link": "https://www.meetup.com/TennisDbls4-0-4-5-SV/events/250467959/", "visibility": "public_limited", "group": {"created": 1430872354000, "name": "Tennis Doubles (only) 4.0-4.5 (only) - Sunnyvale", "id": 18578172, "join_mode": "approval", "lat": 37.380001068115234, "lon": -122.0199966430664, "urlname": "TennisDbls4-0-4-5-SV", "who": "Passionate dbls players", "localized_location": "Sunnyvale, CA", "region": "en_US"}, "waitlist_count": 0, "yes_rsvp_count": 2, "time": 1526140800000, "utc_offset": -25200000, "name": "SAT 9AM", "id": "vrgwmpyxhbqb"}, {"created": 1525218352000, "duration": 34200000, "id": "250354466", "name": "Startup Saturday - Makers and Founders + Networking", "status": "upcoming", "time": 1527953400000, "local_date": "2018-06-02", "local_time": "08:30", "updated": 1525584928000, "utc_offset": -25200000, "waitlist_count": 0, "yes_rsvp_count": 1, "venue": {"id": 25373941, "name": "4701 Patrick Henry Dr", "lat": 37.39841079711914, "lon": -121.98309326171875, "repinned": false, "address_1": "4701 Patrick Henry Drive", "city": "Santa Clara", "country": "US", "localized_country_name": "USA"}, "group": {"created": 1333751549000, "name": "Startup Cofounders", "id": 3620912, "join_mode": "open", "lat": 37.41999816894531, "lon": -122.12999725341797, "urlname": "cofounder", "who": "Founders", "localized_location": "Palo Alto, CA", "region": "en_US"}, "link": "https://www.meetup.com/cofounder/events/250354466/", "description": "<p>*** Purchase a ticket to attend. See below for more information. ***</p> <p>Join us and build your startup or prototype!</p> <p>1. Come up with an idea.<br/>2. Form a team.<br/>3. Validate.<br/>4. Create a prototype.<br/>5. Pitch! (+ networking)</p> <p>Do you want to start a new venture but aren\u2019t sure where to start?<br/>Are you searching for a co-founder but don\u2019t know where to look?<br/>Are you going to various networking events, but can\u2019t find like-minded people?</p> <p>Startup Saturday \u2013 Makers and Founders is a one-day event dedicated in helping you find your technical co-founder, connect with a business co-founder, and create a prototype. In this event, you bring a previously non-prototyped idea, and work with a team of business people and developers to create magic. Along the way, you will get a chance to learn many things about what startup is, all in one day!</p> <p>We will provide lunch, all you need is to bring an idea, that has no prior prototype, so you can validate it. We will form about five teams which consist of at least 2 business professionals and 3 developers/makers per team.</p> <p>______________________________________________<br/>Register for your event tickets at:<br/>______________________________________________</p> <p><a href=\"https://www.eventbrite.com/e/startup-saturday-makers-and-founders-networking-tickets-45604286649\" class=\"linkified\">https://www.eventbrite.com/e/startup-saturday-makers ...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\ProgramData\Miniconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     379             try:  # Python 2.7, use buffering of HTTP responses
# --> 380                 httplib_response = conn.getresponse(buffering=True)
#     381             except TypeError:  # Python 2.6 and older, Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-d675ac9c2310> in <module>()
#      30     return data
#      31
# ---> 32 main()
#
# <ipython-input-2-d675ac9c2310> in main()
#      13         while (results_we_got == per_page):
#      14             # Meetup.com documentation here: http://www.meetup.com/meetup_api/docs/2/groups/
# ---> 15             response=get_results({"sign":"true","country":"US", "city":city, "state":state, "radius": 10, "key":api_key, "page":per_page, "offset":offset })
#      16             time.sleep(1)
#      17             offset += 1
#
# <ipython-input-2-d675ac9c2310> in get_results(params)
#      26
#      27 def get_results(params):
# ---> 28     request = requests.get("http://api.meetup.com/find/upcoming_events",params=params)
#      29     data = request.json()
#      30     return data
#
# C:\ProgramData\Miniconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# C:\ProgramData\Miniconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# C:\ProgramData\Miniconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     506         }
#     507         send_kwargs.update(settings)
# --> 508         resp = self.send(prep, **send_kwargs)
#     509
#     510         return resp
#
# C:\ProgramData\Miniconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     616
#     617         # Send the request
# --> 618         r = adapter.send(request, **kwargs)
#     619
#     620         # Total elapsed time of the request (approximately)
#
# C:\ProgramData\Miniconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438                     decode_content=False,
#     439                     retries=self.max_retries,
# --> 440                     timeout=timeout
#     441                 )
#     442
#
# C:\ProgramData\Miniconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   timeout=timeout_obj,
#     600                                                   body=body, headers=headers,
# --> 601                                                   chunked=chunked)
#     602
#     603             # If we're going to release the connection in ``finally:``, then
#
# C:\ProgramData\Miniconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     381             except TypeError:  # Python 2.6 and older, Python 3
#     382                 try:
# --> 383                     httplib_response = conn.getresponse()
#     384                 except Exception as e:
#     385                     # Remove the TypeError from the exception chain in Python 3;
#
# C:\ProgramData\Miniconda3\lib\http\client.py in getresponse(self)
#    1329         try:
#    1330             try:
# -> 1331                 response.begin()
#    1332             except ConnectionError:
#    1333                 self.close()
#
# C:\ProgramData\Miniconda3\lib\http\client.py in begin(self)
#     295         # read until we get a non-100 response
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#     299                 break
#
# C:\ProgramData\Miniconda3\lib\http\client.py in _read_status(self)
#     256
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#     260             raise LineTooLong("status line")
#
# C:\ProgramData\Miniconda3\lib\socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
print("Test")
# Out:
# Test
